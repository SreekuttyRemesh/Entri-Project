# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_excel("C:\\Users\\sreek\\Downloads\\dataset1.xlsx")
data
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
data['Height']=170

# %%
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     170     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     170     235
# 2     John Holland  Boston Celtics      30       SG   27     170     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     170     203
# 454      Raul Neto       Utah Jazz      25       PG   24     170     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     170     256
# 456    Jeff Withey       Utah Jazz      24        C   26     170     231
# 457       Priyanka       Utah Jazz      34        C   25     170     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
fill_values = {'salary': 1000, 'college': 'UNKOWN'}
df_filled = data.fillna(value=fill_values,inplace=True)
df_filled
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     170     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     170     235
# 2     John Holland  Boston Celtics      30       SG   27     170     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     170     203
# 454      Raul Neto       Utah Jazz      25       PG   24     170     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     170     256
# 456    Jeff Withey       Utah Jazz      24        C   26     170     231
# 457       Priyanka       Utah Jazz      34        C   25     170     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
data['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
X=['New Orleans Pelicans',      
'Memphis Grizzlies',         
'Utah Jazz',                 
'New York Knicks',           
'Milwaukee Bucks',          
'Brooklyn Nets',             
'Portland Trail Blazers',    
'Oklahoma City Thunder' ,    
'Denver Nuggets' ,           
'Washington Wizards',        
'Miami Heat',                
'Charlotte Hornets',        
'Atlanta Hawks',             
'San Antonio Spurs',         
'Houston Rockets',           
'Boston Celtics',            
'Indiana Pacers' ,           
'Detroit Pistons' ,          
'Cleveland Cavaliers',       
'Chicago Bulls',             
'Sacramento Kings',          
'Phoenix Suns',              
'Los Angeles Lakers',        
'Los Angeles Clippers',      
'Golden State Warriors',     
'Toronto Raptors',           
'Philadelphia 76ers',        
'Dallas Mavericks',          
'Orlando Magic',             
'Minnesota Timberwolves']

# %%
Y=[19,18,16,16,16,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,14,14]

# %%
percentage=data['Team'].value_counts(normalize=True)*100
percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
total_teams = len(X)
percentages = [count / sum(Y) * 100 for count in Y]

plt.figure(figsize=(12, 8))
plt.barh(X, percentages, color='skyblue')
plt.xlabel('Percentage')
plt.suptitle('ABC COMPANY PVT LTD.')
plt.title('Percentage Splitting Ratios for Different Teams')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ##As per the analysis 30 teams are there, New Orleans Pelicans is having highest number of team members ,19 employees working in New Orleans Pelicans with 4.148472 percentage of total employees .Memphis Grizzlies is on the second position with 18 team members total , 3.930131 percentage of total members are from Memphis Grizzlies .Utah Jaz, New York Knick, Milwaukee Buc having 16 members on their team their  total percentage is 3.493450.Orlando Magic and
# Minnesota Timberwolves are on the end the list both teams having 14 member and their percentage is 3.056769er all other 23 teams are having 15 members on their team with percentage of 3.275109s

# %% [markdown]
# 2.Segregate the employees w.r.t different positions.

# %%
data['Position'].value_counts()
# Out:
# Position
# SG    87
# PF    81
# PG    76
# SF    71
# C     50
# Name: count, dtype: int64

# %%
positions = ['SG', 'PF', 'PG', 'SF', 'C']
values = [102, 100, 92, 85, 79]

# %%
positions = ['SG', 'PF', 'PG', 'SF','C']
values = [102, 100, 92, 85, 79]
explode = (0.1, 0, 0, 0,0)
plt.figure(figsize=(8, 8))
plt.suptitle("ABC COMPANY PVT LTD")
plt.title('Employees on Different Positions')
plt.pie(values, labels=positions, autopct='%1.1f%%', startangle=140, colors=['red', 'green', 'blue', 'purple','yellow'],shadow=True, explode=explode)
plt.show()

# %% [markdown]
# #On basis of given data ABC company has 458 employees with 5 different positions most of employees are in SG and PF positions.
# 0n first position on basis of employees designation SG position having 102 staff  ,second position  designation PF having 100 staff position having 92 employees on 3rd position and SF position 85 employees are there ,On position C only 79 employees are there as per employees count -position C is on the end

# %% [markdown]
# 3.Find from which age group most of the employees belong to.

# %%
data['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
Age=[24, 25, 27, 23, 26, 28, 30, 29, 22, 31, 20, 21, 33, 32, 34, 36, 35, 37, 38, 40, 39, 19],

# %%
Count=[47, 46, 41, 41, 36, 31, 31, 28, 26, 22, 19, 19, 14, 13, 10, 10, 9, 4, 4, 3, 2, 2]

# %%
plt.figure(figsize=(10, 6)) 
plt.scatter(Age, Count, c='blue', marker='h', edgecolors='black', s=100) 
plt.title('Scatter Plot of Age vs Count')  
plt.xlabel('Age')  
plt.ylabel('Count') 
plt.grid(True, linestyle='--', alpha=0.7) 
plt.show()

# %% [markdown]
# #Most of  the employees are under age of 30 and their less than 10 employees on more than 35 age group . Age group 24 on the first position on basis of employees age group ,Only two employees on age group 39and 19.

# %%
data.dropna(inplace=True)

# %%
d=data.sort_values(by=['Salary'],ascending=False)
d.head(25)
# Out:
#                   Name                   Team  Number Position  Age  Height  \
# 33     Carmelo Anthony        New York Knicks       7       SF   32     170
# 339         Chris Bosh             Miami Heat       1       PF   32     170
# 100         Chris Paul   Los Angeles Clippers       3       PG   31     170
# 414       Kevin Durant  Oklahoma City Thunder      35       SF   27     170
# 164       Derrick Rose          Chicago Bulls       1       PG   27     170
# 349        Dwyane Wade             Miami Heat       3       SG   34     170
# 174         Kevin Love    Cleveland Cavaliers       0       PF   27     170
# 294  LaMarcus Aldridge      San Antonio Spurs      12       PF   30     170
# 98      DeAndre Jordan   Los Angeles Clippers       6        C   27     170
# 23         Brook Lopez          Brooklyn Nets      11        C   28     170
# 96       Blake Griffin   Los Angeles Clippers      32       PF   27     170
# ...

# %%
data1=data[['Position','Salary','Team']]
data1
# Out:
#     Position     Salary            Team
# 0         PG  7730337.0  Boston Celtics
# 1         SF  6796117.0  Boston Celtics
# 3         SG  1148640.0  Boston Celtics
# 6         PF  1170960.0  Boston Celtics
# 7          C  2165160.0  Boston Celtics
# ..       ...        ...             ...
# 451       SF   981348.0       Utah Jazz
# 452       PF  2239800.0       Utah Jazz
# 453       PG  2433333.0       Utah Jazz
# 456        C   947276.0       Utah Jazz
# 457        C   947276.0       Utah Jazz
#
# [365 rows x 3 columns]

# %%
v=data1.sort_values(by=['Salary'],ascending=False)
v
# Out:
#     Position      Salary                   Team
# 33        SF  22875000.0        New York Knicks
# 339       PF  22192730.0             Miami Heat
# 100       PG  21468695.0   Los Angeles Clippers
# 414       SF  20158622.0  Oklahoma City Thunder
# 164       PG  20093064.0          Chicago Bulls
# ..       ...         ...                    ...
# 184       PG    111444.0        Detroit Pistons
# 175       SG    111196.0    Cleveland Cavaliers
# 135        C     83397.0           Phoenix Suns
# 291       SG     55722.0   New Orleans Pelicans
# 130       PG     55722.0           Phoenix Suns
#
# [365 rows x 3 columns]

# %%
v.head(50)
# Out:
#     Position      Salary                   Team
# 33        SF  22875000.0        New York Knicks
# 339       PF  22192730.0             Miami Heat
# 100       PG  21468695.0   Los Angeles Clippers
# 414       SF  20158622.0  Oklahoma City Thunder
# 164       PG  20093064.0          Chicago Bulls
# 349       SG  20000000.0             Miami Heat
# 174       PF  19689000.0    Cleveland Cavaliers
# 294       PF  19689000.0      San Antonio Spurs
# 98         C  19689000.0   Los Angeles Clippers
# 23         C  19689000.0          Brooklyn Nets
# 96        PF  18907726.0   Los Angeles Clippers
# 315       PF  18671659.0          Atlanta Hawks
# 199       SF  17120106.0         Indiana Pacers
# 426       PG  16744218.0  Oklahoma City Thunder
# 168       PG  16407501.0    Cleveland Cavaliers
# 301       SF  16407500.0      San Antonio Spurs
# 418        C  16407500.0  Oklahoma City Thunder
# 153       SG  16407500.0          Chicago Bulls
# 220        C  16407500.0        Milwaukee Bucks
# ...

# %% [markdown]
# 4.Find out under which team and position, spending in terms of salary is high.

# %%
grouped_data=data.groupby(['Team','Position'])['Salary'].sum().reset_index()
grouped_data
# Out:
#                    Team Position      Salary
# 0         Atlanta Hawks        C  12000000.0
# 1         Atlanta Hawks       PF  23952268.0
# 2         Atlanta Hawks       PG   8000000.0
# 3         Atlanta Hawks       SF   2000000.0
# 4         Atlanta Hawks       SG  10431032.0
# ..                  ...      ...         ...
# 137  Washington Wizards        C    273038.0
# 138  Washington Wizards       PF  11300000.0
# 139  Washington Wizards       PG  18022415.0
# 140  Washington Wizards       SF  11158800.0
# 141  Washington Wizards       SG  11356992.0
#
# [142 rows x 3 columns]

# %%
high_spending_teams=grouped_data.groupby('Team')['Salary'].sum().idxmax()
high_spending_teams
# Out:
# 'Los Angeles Clippers'

# %%
g=data.loc[data['Team']=='Los Angeles Clippers']
g
# Out:
#                          Name                  Team  Number Position  Age  \
# 91               Cole Aldrich  Los Angeles Clippers      45        C   27
# 92                 Jeff Ayres  Los Angeles Clippers      19       PF   29
# 93             Jamal Crawford  Los Angeles Clippers      11       SG   36
# 94             Branden Dawson  Los Angeles Clippers      22       SF   23
# 95                 Jeff Green  Los Angeles Clippers       8       SF   29
# 96              Blake Griffin  Los Angeles Clippers      32       PF   27
# 97             Wesley Johnson  Los Angeles Clippers      33       SF   28
# 98             DeAndre Jordan  Los Angeles Clippers       6        C   27
# 99   Luc Richard Mbah a Moute  Los Angeles Clippers      12       PF   29
# 100                Chris Paul  Los Angeles Clippers       3       PG   31
# 101               Paul Pierce  Los Angeles Clippers      34       SF   38
# 103                 JJ Redick  Los Angeles Clippers       4       SG   31
# ...

# %% [markdown]
# High spending team is 'Los Angeles Clippers they are paid on range 21468695$ to 111444$ On USD

# %%
high_spending_positions=grouped_data.groupby('Position')['Salary'].sum().idxmax()
high_spending_positions
# Out:
# 'PG'

# %%
p=data.loc[data['Position']=='PG']
p
# Out:
#                   Name                    Team  Number Position  Age  Height  \
# 0        Avery Bradley          Boston Celtics       0       PG   25     170
# 8         Terry Rozier          Boston Celtics      12       PG   22     170
# 9         Marcus Smart          Boston Celtics      36       PG   22     170
# 11       Isaiah Thomas          Boston Celtics       4       PG   27     170
# 19        Jarrett Jack           Brooklyn Nets       2       PG   32     170
# ..                 ...                     ...     ...      ...  ...     ...
# 426  Russell Westbrook   Oklahoma City Thunder       0       PG   27     170
# 436     Damian Lillard  Portland Trail Blazers       0       PG   25     170
# 440      Brian Roberts  Portland Trail Blazers       2       PG   30     170
# 443         Trey Burke               Utah Jazz       3       PG   23     170
# 453       Shelvin Mack               Utah Jazz       8       PG   26     170
#
#      Weight         College      Salary
# ...

# %% [markdown]
# 5.Find if there is any correlation between age and salary , represent it visually.

# %%
t=data[['Age','Salary']]
t
# Out:
#      Age     Salary
# 0     25  7730337.0
# 1     25  6796117.0
# 3     22  1148640.0
# 6     21  1170960.0
# 7     25  2165160.0
# ..   ...        ...
# 451   26   981348.0
# 452   20  2239800.0
# 453   26  2433333.0
# 456   26   947276.0
# 457   25   947276.0
#
# [365 rows x 2 columns]

# %%
Correlation=data['Age'].corr(data['Salary'])
Correlation
# Out:
# 0.1599918934280617

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(x='Age', y='Salary', data=data, s=100, color='green', edgecolor='black', alpha=0.8,)
plt.title('Correlation between of Age vs Salary', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Salary', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.)
sns.regplot(x='Age', y='Salary', data=data, scatter=False, color='red')
plt.show()

# %% [markdown]
# The scatter plot with the regression line and correlation value annotation provides a visual representation of this weak positive relationship.
# The value of 0.16 indicates a weak correlation.Being positive, it indicates that as age increases, salary tends to increase as well. However, the correlation is weak, so the increase is not very strong or consistent.
